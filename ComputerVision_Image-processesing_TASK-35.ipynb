# %% [markdown]
# # 😄😎Hi Pradeep, Here

# %% [markdown]
# https://www.linkedin.com/in/pradeepkvssk/

# %% [markdown]
# # What Computer Vision ?

# %% [raw]
# Computer vision is a field of artificial intelligence (AI) that enables computers and systems to derive meaningful information from digital images, videos and other visual inputs — and take actions or make recommendations based on that information.

# %% [markdown]
# # Live Use-cases of CV (computer vision) :

# %% [markdown]
# ![t4.jpg](attachment:t4.jpg)
# ![t1.jpg](attachment:t1.jpg)
# ![t2.jpg](attachment:t2.jpg)
# ![t3.jpg](attachment:t3.jpg)

# %%
# LETS GET STARTED

# %% [markdown]
# # Image-processesing via created images:

# %%
import numpy as np
a = np.array([255,0,0])
a

# %% [markdown]
# # Successfully Created a Gif

# %%
# importing the modules
import numpy as np
import cv2

# creating array using np.zeroes()
array = np.zeros([500, 500, 3],dtype = np.uint8)

# setting RGB color values as 255,255,255
j=50
k=0
array[:, :] = [150, 255, 0]
for i in array:
        if i.any()<=255:
                                                         # displaying the image
            array[:,:] = [150,255-j,k]
            k=k+10
            j=j-50
            cv2.imshow("image", array)
            if cv2.waitKey(10)==13:
                break
        else:
            break

cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

# %% [markdown]
# # It is very important to ADD data-type to generate the Image

# %%
array = np.zeros([550,550,3])                             #Without Datatype

# %% [markdown]
# # Created a image and not terminates untill ENTER-key is pressed:

# %%
i1=0
j=0
z=0
array[:,:]= [255,0,255]

for i in array:
    if i.any()<= 255:
        array[:,:]= [i1,j,z]
        i1+=10
        j+=50
        z+=60
        cv2.imshow("new-img",array)
        if cv2.waitKey(10)==13:
            break
    else:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # It is very important to ADD data-type to generate the Image

# %%
array = np.zeros([550,550,3],dtype = np.uint8)                      # With Datatype

# %% [markdown]
# # Created a image and not terminates untill ENTER-key is pressed:

# %%
i1=0
j=0
z=0
array[:,:]= [255,0,255]

for i in array:
    if i.any()<= 255:
        array[:,:]= [i1,j,z]
        i1+=10
        j+=50
        z+=60
        cv2.imshow("new-img",array)
        if cv2.waitKey(10)==13:
            break
    else:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # images are created

# %%
def img(x,y,z):
    array = np.zeros([550,550,3],dtype = np.uint8)  
    array[:,:]=[x,y,z]
    cv2.imshow("img1",array)
    cv2.imwrite("Image1Created.jpg", array)
    cv2.waitKey()
    cv2.destroyAllWindows()

#array1 = np.zeros([550,550,3],dtype = np.uint8)  
#array1[:,:] =[0,255,255] 
#cv2.imshow("img",array)
print("Special Day today ---->>> Enter the numbers today less than 255 ((trust me))")
a=int(input("Hey User tell me one number for your lucky color ------>>>!!!"))
b=int(input("I think i need one more number for your lucky color ------>>>!!!"))
c=int(input("Hey User last number please      --------------------------->>>>>!!!"))
print("Yeah Got your lucky color-->>For TODAY :)")
img(a,b,c)

# %% [markdown]
# # Need the designer image, piled over

# %%
import numpy as np
import cv2, time
i=0
l=[]
def img(x,y,z):
    array2 = np.zeros([550,550,3],dtype = np.uint8)  
    array2[:,:]=[x,y,z]
    #cv2.imwrite("Image1Created.jpg", array)
    #pic = cv2.cvtColor(array2.astype(np.uint8), cv2.COLOR_BGR2RGB)
    l.append(array2)
    
img(10,255,255)
img(150,20,300)
img(255,100,150)
img(255,255,50)
#print(l)


#a=np.array(l)
for i in l:
    time.sleep(2.5)
    cv2.imshow("designer-pic",i)
    if cv2.waitKey(10) == 13:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # Images piled side by side, horizantal & vertically

# %%
import numpy as np
import cv2, time
i=0
l=[]
def img(x,y,z):
    array2 = np.zeros([50,50,3],dtype = np.uint8)  
    array2[:,:]=[x,y,z]
    #cv2.imwrite("Image1Created.jpg", array)
    #pic = cv2.cvtColor(array2.astype(np.uint8), cv2.COLOR_BGR2RGB)
    l.append(array2)
    
img(10,255,255)
img(150,20,300)
img(255,100,150)
img(255,255,200)
#print(l)

listimg = np.concatenate((l[0],l[1],l[2]),axis=1)
cv2.imshow('List of Images --->> Horizanally',listimg)

cv2.waitKey()
cv2.destroyAllWindows()



listimg1 = np.concatenate((l[0],l[1],l[2]),axis=0)
cv2.imshow('List of Images --->> Vertically',listimg1)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Resizing the Images

# %%
import numpy as np
import cv2, time

array = np.zeros([350,350,3],dtype = np.uint8)  
array[:,:]=[150,255,50]
cv2.imshow("img1",array)
cv2.waitKey()
cv2.destroyAllWindows()

# Resizing the image
array2 = cv2.resize(array, (255, 255))
cv2.imshow("img1",array2)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [raw]
# #DONE

# %% [markdown]
# # Cropping of images

# %%
import numpy as np
import cv2

arrayy = np.zeros([350,350,3],dtype = np.uint8)                      # With Datatype

arrayy[:,:]=[255,50,255]
cv2.imshow('Image', arrayy)
cv2.waitKey()
cv2.destroyAllWindows()


y=0
x=0
h=100
w=200
crop = array[y:y+h, x:x+w]
cv2.imshow('Image', crop)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Swapping of images

# %%
import numpy as np
import cv2

temp = np.zeros([550,550,3],dtype = np.uint8)

listtimg1 = np.concatenate((array,arrayy),axis=1)
cv2.imshow('1st Image', listtimg1)
cv2.waitKey()
cv2.destroyAllWindows()

temp=array
array=arrayy
arrayy=temp

listtimg2 = np.concatenate((array,arrayy),axis=1)
cv2.imshow('2nd Image', listtimg2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#     --------------------->>>>>>>>>>               THANK YOU
